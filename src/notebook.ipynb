# %% [markdown]
# ## 1. 3D Scatter Plot of Measured Points
#
# This Python script utilizes the `numpy` and `matplotlib` libraries to create a 3D scatter plot of measured points. The script reads log files from a specified data folder, where each log file's name follows the format `x_y_z.log`. The script then extracts position values from the filenames, converts them from centimeters to meters, and generates a 3D scatter plot.
#
# The resulting plot provides a visual representation of the measured points' positions in 3D space, where the x, y, and z axes represent the respective position dimensions in meters.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

def main():
    data_folder = "data"
    log_files = [f for f in os.listdir(data_folder) if f.endswith(".log")]

    # Initialize lists to store positions
    x_positions = []
    y_positions = []
    z_positions = []

    for log_file in log_files:
        # Split the filename using underscores
        parts = os.path.splitext(log_file)[0].split('_')
        if len(parts) == 3:
            x, y, z = map(int, parts)
            x_positions.append(x)
            y_positions.append(y)
            z_positions.append(z)

    # Convert positions from cm to meters
    x_positions = np.array(x_positions) / 100.0
    y_positions = np.array(y_positions) / 100.0
    z_positions = np.array(z_positions) / 100.0

    # Create a 3D scatter plot
    fig = plt.figure(figsize=(8, 6))  # Adjust the figsize parameter for larger graphs
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(x_positions, y_positions, z_positions, c='b', marker='o')

    ax.set_xlabel('X Position (m)')
    ax.set_ylabel('Y Position (m)')
    ax.set_zlabel('Z Position (m)')
    ax.set_title('3D Scatter Plot of Measured Points')

    plt.tight_layout() 
    plt.show()

if __name__ == "__main__":
    main()

# %% [markdown]
# ## 2. Data Analysis and Visualization from Log Files
#
# This Python script demonstrates data analysis and visualization from log files containing positional information and quality metrics. The script processes log files in a specified data folder, extracts positional data, calculates metrics like blank space count and average quality, and then saves the results to a CSV file. Finally, it generates two 3D scatter plots based on the saved data, highlighting blank space and average quality using color mapping.
#
# The script showcases how to analyze and visualize data from log files, providing insights into the relationships between positional data, blank space, and average quality through well-crafted 3D scatter plots.

# %%
import os
import csv

data_folder = "data"
output_csv = "data_analysis.csv"

# Initialize the CSV header
csv_header = ["filename", "x", "y", "z", "nb_of_blank_space", "average_quality"]
data_rows = []

# Iterate through log files in the data folder
for log_file in os.listdir(data_folder):
    if log_file.endswith(".log"):
        file_path = os.path.join(data_folder, log_file)
        
        # Extract x, y, z from the filename
        x, y, z = map(float, os.path.splitext(log_file)[0].split('_'))
        
        # Initialize variables for counting blank spaces and calculating average quality
        blank_space_count = 0
        total_quality = 0
        quality_count = 0
        
        # Read and process data from the log file
        with open(file_path, 'r') as f:
            for line in f:
                if line.startswith("POS"):
                    try:
                        parts = line.strip().split(',')
                        if len(parts) >= 5:
                            quality = int(parts[4])
                            total_quality += quality
                            quality_count += 1
                    except:
                        pass
                else:
                    blank_space_count += 1
        
        # Calculate average quality
        average_quality = total_quality / quality_count if quality_count > 0 else 0
        
        # Append data to the rows list
        data_rows.append([log_file, x, y, z, blank_space_count, average_quality])

# Write data to the CSV file
with open(output_csv, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(csv_header)
    writer.writerows(data_rows)

print(f"Results saved to {output_csv}.")

# Initialize empty lists to store data
x_values = []
y_values = []
z_values = []
blank_space_values = []
average_quality_values = []

# Read data from the CSV file
with open(output_csv, 'r') as f:
    reader = csv.DictReader(f)
    for row in reader:
        x_values.append(float(row['x']))
        y_values.append(float(row['y']))
        z_values.append(float(row['z']))
        blank_space_values.append(int(row['nb_of_blank_space']))
        average_quality_values.append(float(row['average_quality']))

# Normalize blank space values for color mapping
blank_space_min = min(blank_space_values)
blank_space_max = max(blank_space_values)
normalized_blank_space = np.interp(blank_space_values, (blank_space_min, blank_space_max), (0, 1))

# Create a single figure for both 3D scatter plots
fig = plt.figure(figsize=(12, 6))  # Adjust the figsize parameter for larger graphs

# Create the first 3D scatter plot for blank space (blue to red color map)
ax_blank = fig.add_subplot(121, projection='3d')
scatter_blank = ax_blank.scatter(x_values, y_values, z_values, c=normalized_blank_space, cmap='coolwarm', marker='o')
ax_blank.set_title("3D Scatter Plot - Blank Space (Blue to Red)")
ax_blank.set_xlabel('X')
ax_blank.set_ylabel('Y')
ax_blank.set_zlabel('Z')
fig.colorbar(scatter_blank, ax=ax_blank, label="Blank Space")

# Create the second 3D scatter plot for average quality (green)
ax_quality = fig.add_subplot(122, projection='3d')
scatter_quality = ax_quality.scatter(x_values, y_values, z_values, c=average_quality_values, cmap='Greens', marker='o')
ax_quality.set_title("3D Scatter Plot - Average Quality (Green)")
ax_quality.set_xlabel('X')
ax_quality.set_ylabel('Y')
ax_quality.set_zlabel('Z')
fig.colorbar(scatter_quality, ax=ax_quality, label="Average Quality")

plt.tight_layout()
plt.show()
# Out:
# Results saved to data_analysis.csv.

# %% [markdown]
# ## 3. Filtering incomplete Log Data
#
# This code is designed to handle log files within a designated folder, addressing the issue of missing or incomplete information due to signal loss during data reception. The script filters out lines that do not conform to the correct syntax (POS,x,y,z,quality_factor), which ensures the integrity of the data.

# %%
import os

data_folder = "data_ext/train"
filtered_folder = "data_filtered_ext"

# Create the filtered folder if it doesn't exist
if not os.path.exists(filtered_folder):
    os.makedirs(filtered_folder)

# Iterate through log files in the data folder
for log_file in os.listdir(data_folder):
    if log_file.endswith(".log"):
        input_file_path = os.path.join(data_folder, log_file)
        output_file_path = os.path.join(filtered_folder, log_file)
        
        # Read the content of the input log file
        with open(input_file_path, 'r') as input_file:
            lines = input_file.readlines()
        
        # Filter out lines that don't match the specified syntax
        valid_lines = [line.strip() for line in lines if line.startswith("POS") and len(line.split(',')) == 5]
        
        # Save the valid lines to the output log file in the filtered folder
        with open(output_file_path, 'w') as output_file:
            output_file.write('\n'.join(valid_lines))

# %% [markdown]
# The script successfully filtered the log files in the "data" folder. It excluded lines with incomplete data or missing information, ensuring that only lines following the format "POS,x,y,z,quality_factor" were retained. Filtered log files were saved in the "data_filtered" folder, maintaining data integrity. Console messages confirmed the filtering and saving process.
#
# This process effectively managed missing signal-induced data issues, resulting in a set of clean log files suitable for analysis or further processing.

# %% [markdown]
# ## 4. Identifying Optimal Sample Size for Model Training
#
# This part is developed to address a critical concern in machine learning: the relationship between sample size, training time, and model performance. The script's primary objective is to determine the number of samples required for efficient model training while achieving a satisfactory level of accuracy.
#
# ### Purpose
#
# The purpose of this script is twofold:
#
# 1. **Evaluate Training Time vs. Sample Size**: By systematically varying the sample size used for model training, the script investigates how the number of samples impacts the time required to train the model. This exploration aims to find an optimal balance between training time and model accuracy.
#
# 2. **Guide Sample Size Selection**: The script's execution results in a collection of trained models for varying sample sizes. Analyzing the training times and model accuracies associated with different sample sizes can guide the selection of an appropriate sample size for future model training tasks.
#
# ### Workflow
#
# 1. **Iterative Exploration**: The script iterates through a range of sample sizes, training a linear regression model for each size.
#
# 2. **Data Preparation**: Log files in the specified "data_filtered" folder are processed. The script reads the last "n" lines from each file, focusing on recent data.
#
# 3. **Model Training**: The linear regression model is trained using the selected data samples. The training time is measured for each training session.
#
# 4. **Model Storage**: The trained models are saved in the "models_all_samples" folder, each with a filename indicating the respective sample size.
#
# 5. **Recording Training Times**: The script records the training time for each model, associating it with the corresponding sample size.
#
# 6. **Outcome Analysis**: The recorded training times are saved in a CSV file, "training_times.csv." This CSV file provides a comprehensive view of how training time scales with varying sample sizes.
#
# ### Why It Matters
#
# Understanding the relationship between sample size and training time is crucial for efficient model development. By identifying the minimum number of samples needed to achieve a desired level of accuracy, practitioners can save computational resources and time. This script empowers data scientists and machine learning practitioners to make informed decisions about sample size selection, leading to streamlined model training processes and improved efficiency.
#
# ### Practical Usage
#
# 1. **Parameter Setup**: Modify the "data_folder", "models_folder", "training_times_csv" and "nb_samples" variables as per your data storage and naming conventions.
#
# 2. **Execution**: Run the script to initiate the training process for different sample sizes.
#
# 3. **Analysis**: Examine the training times recorded in "training_times.csv" to identify trends and pinpoint an optimal sample size for your specific use case.
#
# 4. **Decision Making**: Armed with insights from the script's execution, choose an appropriate sample size for future model training endeavors, striking the right balance between accuracy and training time.

# %%
import os
import joblib
import numpy as np
from sklearn.linear_model import LinearRegression
import time
import csv

data_folder = "data_filtered"
models_folder = "models_all_samples"  # Folder for all models
training_times_csv = "training_times.csv"  # CSV file to save training times
nb_samples = 2505 # the number of lines in the smallest data log file, ensuring code execution without errors

# Create the models folder if it doesn't exist
if not os.path.exists(models_folder):
    os.makedirs(models_folder)

# Initialize an empty list to store training times
training_times = []

# Iterate over the range of n values
for n in range(1, nb_samples):
    X_train = []
    y_train = []

    # Iterate through log files in the data folder
    for log_file in os.listdir(data_folder):
        if log_file.endswith(".log"):
            input_file_path = os.path.join(data_folder, log_file)
            
            # Read the last n lines from the log file
            with open(input_file_path, "r") as file:
                lines = file.readlines()
                lines = lines[-n:]  # Get the last n lines
                
                for line in lines:
                    if line.startswith("POS"):
                        try:
                            data = line.strip().split(",")
                            x = [float(data[1]), float(data[2]), float(data[3])]  # Measured position in meters
                            real_point = [float(val)/100 for val in os.path.splitext(os.path.basename(log_file))[0].split('_')]  # Real point in centimeters
                            X_train.append(x)
                            y_train.append(real_point)
                        except:
                            print(line)

    # Convert lists to arrays
    X_train = np.array(X_train)
    y_train = np.array(y_train)

    # Train a linear regression model and measure time
    start_time = time.time()
    model = LinearRegression()
    model.fit(X_train, y_train)
    end_time = time.time()

    # Save the trained model to the models folder
    model_filename = os.path.join(models_folder, f"model_{n}_samples.pkl")
    joblib.dump(model, model_filename)

    training_time = (end_time - start_time) * 1000 # In ms
    training_times.append((n, training_time))  # Append to the training_times list

# Save training times to a CSV file
with open(training_times_csv, 'w', newline='') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["n", "training_time"])
    csv_writer.writerows(training_times)
    
print(f"Training times saved to {training_times_csv}")
# Out:
# Trained model for n=1 saved to models_all_samples\model_1_samples.pkl - Training time: 1.00 ms
# Trained model for n=2 saved to models_all_samples\model_2_samples.pkl - Training time: 0.92 ms
# Trained model for n=3 saved to models_all_samples\model_3_samples.pkl - Training time: 1.00 ms
# Trained model for n=4 saved to models_all_samples\model_4_samples.pkl - Training time: 1.01 ms
# Trained model for n=5 saved to models_all_samples\model_5_samples.pkl - Training time: 1.01 ms
# Trained model for n=6 saved to models_all_samples\model_6_samples.pkl - Training time: 0.00 ms
# Trained model for n=7 saved to models_all_samples\model_7_samples.pkl - Training time: 1.03 ms
# Trained model for n=8 saved to models_all_samples\model_8_samples.pkl - Training time: 1.00 ms
# Trained model for n=9 saved to models_all_samples\model_9_samples.pkl - Training time: 1.00 ms
# Trained model for n=10 saved to models_all_samples\model_10_samples.pkl - Training time: 0.00 ms
# Trained model for n=11 saved to models_all_samples\model_11_samples.pkl - Training time: 0.00 ms
# Trained model for n=12 saved to models_all_samples\model_12_samples.pkl - Training time: 1.00 ms
# Trained model for n=13 saved to models_all_samples\model_13_samples.pkl - Training time: 1.04 ms
# Trained model for n=14 saved to models_all_samples\model_14_samples.pkl - Training time: 0.99 ms
# Trained model for n=15 saved to models_all_samples\model_15_samples.pkl - Training time: 1.00 ms
# Trained model for n=16 saved to models_all_samples\model_16_samples.pkl - Training time: 0.00 ms
# Trained model for n=17 saved to models_all_samples\model_17_samples.pkl - Training time: 0.97 ms
# Trained model for n=18 saved to models_all_samples\model_18_samples.pkl - Training time: 0.00 ms
# Trained model for n=19 saved to models_all_samples\model_19_samples.pkl - Training time: 0.92 ms
# Trained model for n=20 saved to models_all_samples\model_20_samples.pkl - Training time: 0.00 ms
# Trained model for n=21 saved to models_all_samples\model_21_samples.pkl - Training time: 0.99 ms
# Trained model for n=22 saved to models_all_samples\model_22_samples.pkl - Training time: 1.01 ms
# Trained model for n=23 saved to models_all_samples\model_23_samples.pkl - Training time: 1.01 ms
# Trained model for n=24 saved to models_all_samples\model_24_samples.pkl - Training time: 1.01 ms
# Trained model for n=25 saved to models_all_samples\model_25_samples.pkl - Training time: 1.00 ms
# Trained model for n=26 saved to models_all_samples\model_26_samples.pkl - Training time: 2.10 ms
# Trained model for n=27 saved to models_all_samples\model_27_samples.pkl - Training time: 1.00 ms
# Trained model for n=28 saved to models_all_samples\model_28_samples.pkl - Training time: 1.05 ms
# Trained model for n=29 saved to models_all_samples\model_29_samples.pkl - Training time: 0.97 ms
# Trained model for n=30 saved to models_all_samples\model_30_samples.pkl - Training time: 1.98 ms
# Trained model for n=31 saved to models_all_samples\model_31_samples.pkl - Training time: 2.04 ms
# Trained model for n=32 saved to models_all_samples\model_32_samples.pkl - Training time: 1.09 ms
# Trained model for n=33 saved to models_all_samples\model_33_samples.pkl - Training time: 1.08 ms
# Trained model for n=34 saved to models_all_samples\model_34_samples.pkl - Training time: 2.01 ms
# Trained model for n=35 saved to models_all_samples\model_35_samples.pkl - Training time: 0.00 ms
# Trained model for n=36 saved to models_all_samples\model_36_samples.pkl - Training time: 1.01 ms
# Trained model for n=37 saved to models_all_samples\model_37_samples.pkl - Training time: 0.88 ms
# Trained model for n=38 saved to models_all_samples\model_38_samples.pkl - Training time: 2.08 ms
# Trained model for n=39 saved to models_all_samples\model_39_samples.pkl - Training time: 1.99 ms
# Trained model for n=40 saved to models_all_samples\model_40_samples.pkl - Training time: 1.02 ms
# Trained model for n=41 saved to models_all_samples\model_41_samples.pkl - Training time: 2.00 ms
# Trained model for n=42 saved to models_all_samples\model_42_samples.pkl - Training time: 1.00 ms
# Trained model for n=43 saved to models_all_samples\model_43_samples.pkl - Training time: 1.07 ms
# Trained model for n=44 saved to models_all_samples\model_44_samples.pkl - Training time: 1.02 ms
# Trained model for n=45 saved to models_all_samples\model_45_samples.pkl - Training time: 2.11 ms
# Trained model for n=46 saved to models_all_samples\model_46_samples.pkl - Training time: 2.02 ms
# Trained model for n=47 saved to models_all_samples\model_47_samples.pkl - Training time: 2.01 ms
# Trained model for n=48 saved to models_all_samples\model_48_samples.pkl - Training time: 2.00 ms
# Trained model for n=49 saved to models_all_samples\model_49_samples.pkl - Training time: 1.00 ms
# Trained model for n=50 saved to models_all_samples\model_50_samples.pkl - Training time: 2.00 ms
# Trained model for n=51 saved to models_all_samples\model_51_samples.pkl - Training time: 1.00 ms
# Trained model for n=52 saved to models_all_samples\model_52_samples.pkl - Training time: 0.99 ms
# Trained model for n=53 saved to models_all_samples\model_53_samples.pkl - Training time: 1.04 ms
# Trained model for n=54 saved to models_all_samples\model_54_samples.pkl - Training time: 1.94 ms
# Trained model for n=55 saved to models_all_samples\model_55_samples.pkl - Training time: 0.93 ms
# Trained model for n=56 saved to models_all_samples\model_56_samples.pkl - Training time: 1.93 ms
# Trained model for n=57 saved to models_all_samples\model_57_samples.pkl - Training time: 2.01 ms
# Trained model for n=58 saved to models_all_samples\model_58_samples.pkl - Training time: 1.01 ms
# Trained model for n=59 saved to models_all_samples\model_59_samples.pkl - Training time: 1.94 ms
# Trained model for n=60 saved to models_all_samples\model_60_samples.pkl - Training time: 0.96 ms
# Trained model for n=61 saved to models_all_samples\model_61_samples.pkl - Training time: 1.07 ms
# Trained model for n=62 saved to models_all_samples\model_62_samples.pkl - Training time: 1.03 ms
# Trained model for n=63 saved to models_all_samples\model_63_samples.pkl - Training time: 1.05 ms
# Trained model for n=64 saved to models_all_samples\model_64_samples.pkl - Training time: 0.98 ms
# Trained model for n=65 saved to models_all_samples\model_65_samples.pkl - Training time: 0.97 ms
# Trained model for n=66 saved to models_all_samples\model_66_samples.pkl - Training time: 0.98 ms
# Trained model for n=67 saved to models_all_samples\model_67_samples.pkl - Training time: 2.96 ms
# Trained model for n=68 saved to models_all_samples\model_68_samples.pkl - Training time: 0.97 ms
# Trained model for n=69 saved to models_all_samples\model_69_samples.pkl - Training time: 0.99 ms
# Trained model for n=70 saved to models_all_samples\model_70_samples.pkl - Training time: 0.99 ms
# Trained model for n=71 saved to models_all_samples\model_71_samples.pkl - Training time: 1.01 ms
# Trained model for n=72 saved to models_all_samples\model_72_samples.pkl - Training time: 1.98 ms
# Trained model for n=73 saved to models_all_samples\model_73_samples.pkl - Training time: 1.08 ms
# Trained model for n=74 saved to models_all_samples\model_74_samples.pkl - Training time: 0.99 ms
# Trained model for n=75 saved to models_all_samples\model_75_samples.pkl - Training time: 1.88 ms
# Trained model for n=76 saved to models_all_samples\model_76_samples.pkl - Training time: 1.07 ms
# Trained model for n=77 saved to models_all_samples\model_77_samples.pkl - Training time: 0.92 ms
# Trained model for n=78 saved to models_all_samples\model_78_samples.pkl - Training time: 2.07 ms
# Trained model for n=79 saved to models_all_samples\model_79_samples.pkl - Training time: 0.99 ms
# Trained model for n=80 saved to models_all_samples\model_80_samples.pkl - Training time: 0.99 ms
# Trained model for n=81 saved to models_all_samples\model_81_samples.pkl - Training time: 1.00 ms
# Trained model for n=82 saved to models_all_samples\model_82_samples.pkl - Training time: 1.05 ms
# Trained model for n=83 saved to models_all_samples\model_83_samples.pkl - Training time: 1.08 ms
# Trained model for n=84 saved to models_all_samples\model_84_samples.pkl - Training time: 0.99 ms
# Trained model for n=85 saved to models_all_samples\model_85_samples.pkl - Training time: 2.02 ms
# Trained model for n=86 saved to models_all_samples\model_86_samples.pkl - Training time: 1.00 ms
# Trained model for n=87 saved to models_all_samples\model_87_samples.pkl - Training time: 0.96 ms
# Trained model for n=88 saved to models_all_samples\model_88_samples.pkl - Training time: 1.00 ms
# Trained model for n=89 saved to models_all_samples\model_89_samples.pkl - Training time: 1.00 ms
# Trained model for n=90 saved to models_all_samples\model_90_samples.pkl - Training time: 1.01 ms
# Trained model for n=91 saved to models_all_samples\model_91_samples.pkl - Training time: 1.00 ms
# Trained model for n=92 saved to models_all_samples\model_92_samples.pkl - Training time: 1.02 ms
# Trained model for n=93 saved to models_all_samples\model_93_samples.pkl - Training time: 1.00 ms
# Trained model for n=94 saved to models_all_samples\model_94_samples.pkl - Training time: 1.01 ms
# Trained model for n=95 saved to models_all_samples\model_95_samples.pkl - Training time: 3.00 ms
# Trained model for n=96 saved to models_all_samples\model_96_samples.pkl - Training time: 2.01 ms
# Trained model for n=97 saved to models_all_samples\model_97_samples.pkl - Training time: 2.00 ms
# Trained model for n=98 saved to models_all_samples\model_98_samples.pkl - Training time: 1.98 ms
# Trained model for n=99 saved to models_all_samples\model_99_samples.pkl - Training time: 1.99 ms
# Trained model for n=100 saved to models_all_samples\model_100_samples.pkl - Training time: 2.00 ms
# Trained model for n=101 saved to models_all_samples\model_101_samples.pkl - Training time: 2.00 ms
# Trained model for n=102 saved to models_all_samples\model_102_samples.pkl - Training time: 2.00 ms
# Trained model for n=103 saved to models_all_samples\model_103_samples.pkl - Training time: 3.00 ms
# Trained model for n=104 saved to models_all_samples\model_104_samples.pkl - Training time: 1.00 ms
# Trained model for n=105 saved to models_all_samples\model_105_samples.pkl - Training time: 1.00 ms
# Trained model for n=106 saved to models_all_samples\model_106_samples.pkl - Training time: 1.01 ms
# Trained model for n=107 saved to models_all_samples\model_107_samples.pkl - Training time: 2.00 ms
# Trained model for n=108 saved to models_all_samples\model_108_samples.pkl - Training time: 1.00 ms
# Trained model for n=109 saved to models_all_samples\model_109_samples.pkl - Training time: 2.02 ms
# Trained model for n=110 saved to models_all_samples\model_110_samples.pkl - Training time: 1.01 ms
# Trained model for n=111 saved to models_all_samples\model_111_samples.pkl - Training time: 2.02 ms
# Trained model for n=112 saved to models_all_samples\model_112_samples.pkl - Training time: 1.00 ms
# Trained model for n=113 saved to models_all_samples\model_113_samples.pkl - Training time: 2.51 ms
# Trained model for n=114 saved to models_all_samples\model_114_samples.pkl - Training time: 2.01 ms
# Trained model for n=115 saved to models_all_samples\model_115_samples.pkl - Training time: 2.01 ms
# Trained model for n=116 saved to models_all_samples\model_116_samples.pkl - Training time: 1.00 ms
# Trained model for n=117 saved to models_all_samples\model_117_samples.pkl - Training time: 2.00 ms
# Trained model for n=118 saved to models_all_samples\model_118_samples.pkl - Training time: 1.00 ms
# Trained model for n=119 saved to models_all_samples\model_119_samples.pkl - Training time: 2.02 ms
# Trained model for n=120 saved to models_all_samples\model_120_samples.pkl - Training time: 1.99 ms
# Trained model for n=121 saved to models_all_samples\model_121_samples.pkl - Training time: 2.98 ms
# Trained model for n=122 saved to models_all_samples\model_122_samples.pkl - Training time: 3.00 ms
# Trained model for n=123 saved to models_all_samples\model_123_samples.pkl - Training time: 2.93 ms
# Trained model for n=124 saved to models_all_samples\model_124_samples.pkl - Training time: 1.00 ms
# Trained model for n=125 saved to models_all_samples\model_125_samples.pkl - Training time: 1.00 ms
# Trained model for n=126 saved to models_all_samples\model_126_samples.pkl - Training time: 2.00 ms
# Trained model for n=127 saved to models_all_samples\model_127_samples.pkl - Training time: 1.00 ms
# Trained model for n=128 saved to models_all_samples\model_128_samples.pkl - Training time: 1.92 ms
# Trained model for n=129 saved to models_all_samples\model_129_samples.pkl - Training time: 2.94 ms
# Trained model for n=130 saved to models_all_samples\model_130_samples.pkl - Training time: 3.01 ms
# Trained model for n=131 saved to models_all_samples\model_131_samples.pkl - Training time: 2.06 ms
# Trained model for n=132 saved to models_all_samples\model_132_samples.pkl - Training time: 3.01 ms
# Trained model for n=133 saved to models_all_samples\model_133_samples.pkl - Training time: 1.95 ms
# Trained model for n=134 saved to models_all_samples\model_134_samples.pkl - Training time: 1.00 ms
# Trained model for n=135 saved to models_all_samples\model_135_samples.pkl - Training time: 3.98 ms
# Trained model for n=136 saved to models_all_samples\model_136_samples.pkl - Training time: 2.04 ms
# Trained model for n=137 saved to models_all_samples\model_137_samples.pkl - Training time: 1.02 ms
# Trained model for n=138 saved to models_all_samples\model_138_samples.pkl - Training time: 2.03 ms
# Trained model for n=139 saved to models_all_samples\model_139_samples.pkl - Training time: 2.03 ms
# Trained model for n=140 saved to models_all_samples\model_140_samples.pkl - Training time: 2.97 ms
# Trained model for n=141 saved to models_all_samples\model_141_samples.pkl - Training time: 1.93 ms
# Trained model for n=142 saved to models_all_samples\model_142_samples.pkl - Training time: 1.02 ms
# Trained model for n=143 saved to models_all_samples\model_143_samples.pkl - Training time: 1.94 ms
# Trained model for n=144 saved to models_all_samples\model_144_samples.pkl - Training time: 2.01 ms
# Trained model for n=145 saved to models_all_samples\model_145_samples.pkl - Training time: 2.00 ms
# Trained model for n=146 saved to models_all_samples\model_146_samples.pkl - Training time: 1.93 ms
# Trained model for n=147 saved to models_all_samples\model_147_samples.pkl - Training time: 3.52 ms
# Trained model for n=148 saved to models_all_samples\model_148_samples.pkl - Training time: 3.99 ms
# Trained model for n=149 saved to models_all_samples\model_149_samples.pkl - Training time: 1.00 ms
# Trained model for n=150 saved to models_all_samples\model_150_samples.pkl - Training time: 1.99 ms
# Trained model for n=151 saved to models_all_samples\model_151_samples.pkl - Training time: 3.07 ms
# Trained model for n=152 saved to models_all_samples\model_152_samples.pkl - Training time: 3.93 ms
# Trained model for n=153 saved to models_all_samples\model_153_samples.pkl - Training time: 1.99 ms
# Trained model for n=154 saved to models_all_samples\model_154_samples.pkl - Training time: 1.95 ms
# Trained model for n=155 saved to models_all_samples\model_155_samples.pkl - Training time: 2.06 ms
# Trained model for n=156 saved to models_all_samples\model_156_samples.pkl - Training time: 1.96 ms
# Trained model for n=157 saved to models_all_samples\model_157_samples.pkl - Training time: 1.06 ms
# Trained model for n=158 saved to models_all_samples\model_158_samples.pkl - Training time: 1.02 ms
# Trained model for n=159 saved to models_all_samples\model_159_samples.pkl - Training time: 2.00 ms
# Trained model for n=160 saved to models_all_samples\model_160_samples.pkl - Training time: 1.99 ms
# Trained model for n=161 saved to models_all_samples\model_161_samples.pkl - Training time: 1.93 ms
# Trained model for n=162 saved to models_all_samples\model_162_samples.pkl - Training time: 2.01 ms
# Trained model for n=163 saved to models_all_samples\model_163_samples.pkl - Training time: 2.98 ms
# Trained model for n=164 saved to models_all_samples\model_164_samples.pkl - Training time: 3.00 ms
# Trained model for n=165 saved to models_all_samples\model_165_samples.pkl - Training time: 1.00 ms
# Trained model for n=166 saved to models_all_samples\model_166_samples.pkl - Training time: 3.00 ms
# Trained model for n=167 saved to models_all_samples\model_167_samples.pkl - Training time: 2.00 ms
# Trained model for n=168 saved to models_all_samples\model_168_samples.pkl - Training time: 1.00 ms
# Trained model for n=169 saved to models_all_samples\model_169_samples.pkl - Training time: 2.00 ms
# Trained model for n=170 saved to models_all_samples\model_170_samples.pkl - Training time: 3.00 ms
# Trained model for n=171 saved to models_all_samples\model_171_samples.pkl - Training time: 1.99 ms
# Trained model for n=172 saved to models_all_samples\model_172_samples.pkl - Training time: 4.01 ms
# Trained model for n=173 saved to models_all_samples\model_173_samples.pkl - Training time: 3.00 ms
# Trained model for n=174 saved to models_all_samples\model_174_samples.pkl - Training time: 1.51 ms
# Trained model for n=175 saved to models_all_samples\model_175_samples.pkl - Training time: 3.03 ms
# Trained model for n=176 saved to models_all_samples\model_176_samples.pkl - Training time: 3.99 ms
# Trained model for n=177 saved to models_all_samples\model_177_samples.pkl - Training time: 2.00 ms
# Trained model for n=178 saved to models_all_samples\model_178_samples.pkl - Training time: 1.00 ms
# Trained model for n=179 saved to models_all_samples\model_179_samples.pkl - Training time: 2.00 ms
# Trained model for n=180 saved to models_all_samples\model_180_samples.pkl - Training time: 3.00 ms
# Trained model for n=181 saved to models_all_samples\model_181_samples.pkl - Training time: 2.00 ms
# Trained model for n=182 saved to models_all_samples\model_182_samples.pkl - Training time: 3.00 ms
# Trained model for n=183 saved to models_all_samples\model_183_samples.pkl - Training time: 1.97 ms
# Trained model for n=184 saved to models_all_samples\model_184_samples.pkl - Training time: 2.00 ms
# Trained model for n=185 saved to models_all_samples\model_185_samples.pkl - Training time: 2.02 ms
# Trained model for n=186 saved to models_all_samples\model_186_samples.pkl - Training time: 3.00 ms
# Trained model for n=187 saved to models_all_samples\model_187_samples.pkl - Training time: 2.00 ms
# Trained model for n=188 saved to models_all_samples\model_188_samples.pkl - Training time: 3.00 ms
# Trained model for n=189 saved to models_all_samples\model_189_samples.pkl - Training time: 1.97 ms
# Trained model for n=190 saved to models_all_samples\model_190_samples.pkl - Training time: 2.00 ms
# Trained model for n=191 saved to models_all_samples\model_191_samples.pkl - Training time: 1.00 ms
# Trained model for n=192 saved to models_all_samples\model_192_samples.pkl - Training time: 0.99 ms
# Trained model for n=193 saved to models_all_samples\model_193_samples.pkl - Training time: 2.98 ms
# Trained model for n=194 saved to models_all_samples\model_194_samples.pkl - Training time: 2.00 ms
# Trained model for n=195 saved to models_all_samples\model_195_samples.pkl - Training time: 2.99 ms
# Trained model for n=196 saved to models_all_samples\model_196_samples.pkl - Training time: 3.00 ms
# Trained model for n=197 saved to models_all_samples\model_197_samples.pkl - Training time: 3.00 ms
# Trained model for n=198 saved to models_all_samples\model_198_samples.pkl - Training time: 3.00 ms
# Trained model for n=199 saved to models_all_samples\model_199_samples.pkl - Training time: 2.01 ms
# Trained model for n=200 saved to models_all_samples\model_200_samples.pkl - Training time: 3.98 ms
# Trained model for n=201 saved to models_all_samples\model_201_samples.pkl - Training time: 2.00 ms
# Trained model for n=202 saved to models_all_samples\model_202_samples.pkl - Training time: 3.00 ms
# Trained model for n=203 saved to models_all_samples\model_203_samples.pkl - Training time: 3.00 ms
# Trained model for n=204 saved to models_all_samples\model_204_samples.pkl - Training time: 2.97 ms
# Trained model for n=205 saved to models_all_samples\model_205_samples.pkl - Training time: 4.00 ms
# Trained model for n=206 saved to models_all_samples\model_206_samples.pkl - Training time: 2.00 ms
# Trained model for n=207 saved to models_all_samples\model_207_samples.pkl - Training time: 2.00 ms
# Trained model for n=208 saved to models_all_samples\model_208_samples.pkl - Training time: 4.00 ms
# Trained model for n=209 saved to models_all_samples\model_209_samples.pkl - Training time: 4.00 ms
# Trained model for n=210 saved to models_all_samples\model_210_samples.pkl - Training time: 2.00 ms
# Trained model for n=211 saved to models_all_samples\model_211_samples.pkl - Training time: 1.99 ms
# Trained model for n=212 saved to models_all_samples\model_212_samples.pkl - Training time: 2.00 ms
# Trained model for n=213 saved to models_all_samples\model_213_samples.pkl - Training time: 3.02 ms
# Trained model for n=214 saved to models_all_samples\model_214_samples.pkl - Training time: 2.00 ms
# Trained model for n=215 saved to models_all_samples\model_215_samples.pkl - Training time: 3.00 ms
# Trained model for n=216 saved to models_all_samples\model_216_samples.pkl - Training time: 4.01 ms
# Trained model for n=217 saved to models_all_samples\model_217_samples.pkl - Training time: 3.01 ms
# Trained model for n=218 saved to models_all_samples\model_218_samples.pkl - Training time: 3.03 ms
# Trained model for n=219 saved to models_all_samples\model_219_samples.pkl - Training time: 3.02 ms
# Trained model for n=220 saved to models_all_samples\model_220_samples.pkl - Training time: 3.99 ms
# Trained model for n=221 saved to models_all_samples\model_221_samples.pkl - Training time: 3.00 ms
# Trained model for n=222 saved to models_all_samples\model_222_samples.pkl - Training time: 2.00 ms
# Trained model for n=223 saved to models_all_samples\model_223_samples.pkl - Training time: 2.00 ms
# Trained model for n=224 saved to models_all_samples\model_224_samples.pkl - Training time: 3.99 ms
# Trained model for n=225 saved to models_all_samples\model_225_samples.pkl - Training time: 3.00 ms
# Trained model for n=226 saved to models_all_samples\model_226_samples.pkl - Training time: 3.03 ms
# Trained model for n=227 saved to models_all_samples\model_227_samples.pkl - Training time: 2.08 ms
# Trained model for n=228 saved to models_all_samples\model_228_samples.pkl - Training time: 1.98 ms
# Trained model for n=229 saved to models_all_samples\model_229_samples.pkl - Training time: 3.08 ms
# Trained model for n=230 saved to models_all_samples\model_230_samples.pkl - Training time: 2.06 ms
# Trained model for n=231 saved to models_all_samples\model_231_samples.pkl - Training time: 3.90 ms
# Trained model for n=232 saved to models_all_samples\model_232_samples.pkl - Training time: 2.00 ms
# Trained model for n=233 saved to models_all_samples\model_233_samples.pkl - Training time: 4.00 ms
# Trained model for n=234 saved to models_all_samples\model_234_samples.pkl - Training time: 4.00 ms
# Trained model for n=235 saved to models_all_samples\model_235_samples.pkl - Training time: 3.52 ms
# Trained model for n=236 saved to models_all_samples\model_236_samples.pkl - Training time: 4.01 ms
# Trained model for n=237 saved to models_all_samples\model_237_samples.pkl - Training time: 3.12 ms
# Trained model for n=238 saved to models_all_samples\model_238_samples.pkl - Training time: 2.00 ms
# Trained model for n=239 saved to models_all_samples\model_239_samples.pkl - Training time: 4.00 ms
# Trained model for n=240 saved to models_all_samples\model_240_samples.pkl - Training time: 1.99 ms
# Trained model for n=241 saved to models_all_samples\model_241_samples.pkl - Training time: 3.01 ms
# Trained model for n=242 saved to models_all_samples\model_242_samples.pkl - Training time: 3.02 ms
# Trained model for n=243 saved to models_all_samples\model_243_samples.pkl - Training time: 3.01 ms
# Trained model for n=244 saved to models_all_samples\model_244_samples.pkl - Training time: 2.00 ms
# Trained model for n=245 saved to models_all_samples\model_245_samples.pkl - Training time: 4.00 ms
# Trained model for n=246 saved to models_all_samples\model_246_samples.pkl - Training time: 3.00 ms
# Trained model for n=247 saved to models_all_samples\model_247_samples.pkl - Training time: 4.00 ms
# Trained model for n=248 saved to models_all_samples\model_248_samples.pkl - Training time: 7.01 ms
# Trained model for n=249 saved to models_all_samples\model_249_samples.pkl - Training time: 4.00 ms
# Trained model for n=250 saved to models_all_samples\model_250_samples.pkl - Training time: 4.00 ms
# Trained model for n=251 saved to models_all_samples\model_251_samples.pkl - Training time: 3.50 ms
# Trained model for n=252 saved to models_all_samples\model_252_samples.pkl - Training time: 3.00 ms
# Trained model for n=253 saved to models_all_samples\model_253_samples.pkl - Training time: 4.51 ms
# Trained model for n=254 saved to models_all_samples\model_254_samples.pkl - Training time: 3.99 ms
# Trained model for n=255 saved to models_all_samples\model_255_samples.pkl - Training time: 5.00 ms
# Trained model for n=256 saved to models_all_samples\model_256_samples.pkl - Training time: 2.97 ms
# Trained model for n=257 saved to models_all_samples\model_257_samples.pkl - Training time: 4.00 ms
# Trained model for n=258 saved to models_all_samples\model_258_samples.pkl - Training time: 3.96 ms
# Trained model for n=259 saved to models_all_samples\model_259_samples.pkl - Training time: 2.98 ms
# Trained model for n=260 saved to models_all_samples\model_260_samples.pkl - Training time: 4.48 ms
# Trained model for n=261 saved to models_all_samples\model_261_samples.pkl - Training time: 3.00 ms
# Trained model for n=262 saved to models_all_samples\model_262_samples.pkl - Training time: 4.00 ms
# Trained model for n=263 saved to models_all_samples\model_263_samples.pkl - Training time: 4.00 ms
# Trained model for n=264 saved to models_all_samples\model_264_samples.pkl - Training time: 3.00 ms
# Trained model for n=265 saved to models_all_samples\model_265_samples.pkl - Training time: 4.00 ms
# Trained model for n=266 saved to models_all_samples\model_266_samples.pkl - Training time: 3.01 ms
# Trained model for n=267 saved to models_all_samples\model_267_samples.pkl - Training time: 5.00 ms
# Trained model for n=268 saved to models_all_samples\model_268_samples.pkl - Training time: 3.00 ms
# Trained model for n=269 saved to models_all_samples\model_269_samples.pkl - Training time: 2.00 ms
# Trained model for n=270 saved to models_all_samples\model_270_samples.pkl - Training time: 4.00 ms
# Trained model for n=271 saved to models_all_samples\model_271_samples.pkl - Training time: 3.98 ms
# Trained model for n=272 saved to models_all_samples\model_272_samples.pkl - Training time: 4.74 ms
# Trained model for n=273 saved to models_all_samples\model_273_samples.pkl - Training time: 4.00 ms
# Trained model for n=274 saved to models_all_samples\model_274_samples.pkl - Training time: 4.01 ms
# Trained model for n=275 saved to models_all_samples\model_275_samples.pkl - Training time: 3.51 ms
# Trained model for n=276 saved to models_all_samples\model_276_samples.pkl - Training time: 3.00 ms
# Trained model for n=277 saved to models_all_samples\model_277_samples.pkl - Training time: 4.03 ms
# Trained model for n=278 saved to models_all_samples\model_278_samples.pkl - Training time: 4.00 ms
# Trained model for n=279 saved to models_all_samples\model_279_samples.pkl - Training time: 3.00 ms
# Trained model for n=280 saved to models_all_samples\model_280_samples.pkl - Training time: 3.00 ms
# Trained model for n=281 saved to models_all_samples\model_281_samples.pkl - Training time: 3.00 ms
# Trained model for n=282 saved to models_all_samples\model_282_samples.pkl - Training time: 3.01 ms
# Trained model for n=283 saved to models_all_samples\model_283_samples.pkl - Training time: 4.10 ms
# Trained model for n=284 saved to models_all_samples\model_284_samples.pkl - Training time: 3.94 ms
# Trained model for n=285 saved to models_all_samples\model_285_samples.pkl - Training time: 3.94 ms
# Trained model for n=286 saved to models_all_samples\model_286_samples.pkl - Training time: 5.00 ms
# Trained model for n=287 saved to models_all_samples\model_287_samples.pkl - Training time: 4.07 ms
# Trained model for n=288 saved to models_all_samples\model_288_samples.pkl - Training time: 4.01 ms
# Trained model for n=289 saved to models_all_samples\model_289_samples.pkl - Training time: 4.04 ms
# Trained model for n=290 saved to models_all_samples\model_290_samples.pkl - Training time: 5.00 ms
# Trained model for n=291 saved to models_all_samples\model_291_samples.pkl - Training time: 2.99 ms
# Trained model for n=292 saved to models_all_samples\model_292_samples.pkl - Training time: 3.94 ms
# Trained model for n=293 saved to models_all_samples\model_293_samples.pkl - Training time: 3.08 ms
# Trained model for n=294 saved to models_all_samples\model_294_samples.pkl - Training time: 4.03 ms
# Trained model for n=295 saved to models_all_samples\model_295_samples.pkl - Training time: 2.98 ms
# Trained model for n=296 saved to models_all_samples\model_296_samples.pkl - Training time: 5.00 ms
# Trained model for n=297 saved to models_all_samples\model_297_samples.pkl - Training time: 3.01 ms
# Trained model for n=298 saved to models_all_samples\model_298_samples.pkl - Training time: 6.00 ms
# Trained model for n=299 saved to models_all_samples\model_299_samples.pkl - Training time: 3.00 ms
# Trained model for n=300 saved to models_all_samples\model_300_samples.pkl - Training time: 5.00 ms
# Trained model for n=301 saved to models_all_samples\model_301_samples.pkl - Training time: 3.00 ms
# Trained model for n=302 saved to models_all_samples\model_302_samples.pkl - Training time: 3.00 ms
# Trained model for n=303 saved to models_all_samples\model_303_samples.pkl - Training time: 4.00 ms
# Trained model for n=304 saved to models_all_samples\model_304_samples.pkl - Training time: 5.00 ms
# Trained model for n=305 saved to models_all_samples\model_305_samples.pkl - Training time: 4.51 ms
# Trained model for n=306 saved to models_all_samples\model_306_samples.pkl - Training time: 4.01 ms
# Trained model for n=307 saved to models_all_samples\model_307_samples.pkl - Training time: 5.00 ms
# Trained model for n=308 saved to models_all_samples\model_308_samples.pkl - Training time: 4.00 ms
# Trained model for n=309 saved to models_all_samples\model_309_samples.pkl - Training time: 8.00 ms
# Trained model for n=310 saved to models_all_samples\model_310_samples.pkl - Training time: 8.03 ms
# Trained model for n=311 saved to models_all_samples\model_311_samples.pkl - Training time: 8.13 ms
# Trained model for n=312 saved to models_all_samples\model_312_samples.pkl - Training time: 5.33 ms
# Trained model for n=313 saved to models_all_samples\model_313_samples.pkl - Training time: 2.93 ms
# Trained model for n=314 saved to models_all_samples\model_314_samples.pkl - Training time: 4.07 ms
# Trained model for n=315 saved to models_all_samples\model_315_samples.pkl - Training time: 3.98 ms
# Trained model for n=316 saved to models_all_samples\model_316_samples.pkl - Training time: 4.98 ms
# Trained model for n=317 saved to models_all_samples\model_317_samples.pkl - Training time: 3.99 ms
# Trained model for n=318 saved to models_all_samples\model_318_samples.pkl - Training time: 6.02 ms
# Trained model for n=319 saved to models_all_samples\model_319_samples.pkl - Training time: 4.53 ms
# Trained model for n=320 saved to models_all_samples\model_320_samples.pkl - Training time: 3.01 ms
# Trained model for n=321 saved to models_all_samples\model_321_samples.pkl - Training time: 5.00 ms
# Trained model for n=322 saved to models_all_samples\model_322_samples.pkl - Training time: 4.00 ms
# Trained model for n=323 saved to models_all_samples\model_323_samples.pkl - Training time: 5.20 ms
# Trained model for n=324 saved to models_all_samples\model_324_samples.pkl - Training time: 4.53 ms
# Trained model for n=325 saved to models_all_samples\model_325_samples.pkl - Training time: 6.00 ms
# Trained model for n=326 saved to models_all_samples\model_326_samples.pkl - Training time: 6.66 ms
# Trained model for n=327 saved to models_all_samples\model_327_samples.pkl - Training time: 5.05 ms
# Trained model for n=328 saved to models_all_samples\model_328_samples.pkl - Training time: 3.97 ms
# Trained model for n=329 saved to models_all_samples\model_329_samples.pkl - Training time: 3.01 ms
# Trained model for n=330 saved to models_all_samples\model_330_samples.pkl - Training time: 4.00 ms
# Trained model for n=331 saved to models_all_samples\model_331_samples.pkl - Training time: 4.63 ms
# Trained model for n=332 saved to models_all_samples\model_332_samples.pkl - Training time: 3.97 ms
# Trained model for n=333 saved to models_all_samples\model_333_samples.pkl - Training time: 4.01 ms
# Trained model for n=334 saved to models_all_samples\model_334_samples.pkl - Training time: 5.00 ms
# Trained model for n=335 saved to models_all_samples\model_335_samples.pkl - Training time: 4.04 ms
# Trained model for n=336 saved to models_all_samples\model_336_samples.pkl - Training time: 6.00 ms
# Trained model for n=337 saved to models_all_samples\model_337_samples.pkl - Training time: 5.98 ms
# Trained model for n=338 saved to models_all_samples\model_338_samples.pkl - Training time: 4.99 ms
# Trained model for n=339 saved to models_all_samples\model_339_samples.pkl - Training time: 4.54 ms
# Trained model for n=340 saved to models_all_samples\model_340_samples.pkl - Training time: 8.63 ms
# Trained model for n=341 saved to models_all_samples\model_341_samples.pkl - Training time: 6.08 ms
# Trained model for n=342 saved to models_all_samples\model_342_samples.pkl - Training time: 5.06 ms
# Trained model for n=343 saved to models_all_samples\model_343_samples.pkl - Training time: 4.98 ms
# Trained model for n=344 saved to models_all_samples\model_344_samples.pkl - Training time: 6.09 ms
# Trained model for n=345 saved to models_all_samples\model_345_samples.pkl - Training time: 5.03 ms
# Trained model for n=346 saved to models_all_samples\model_346_samples.pkl - Training time: 5.00 ms
# Trained model for n=347 saved to models_all_samples\model_347_samples.pkl - Training time: 6.94 ms
# Trained model for n=348 saved to models_all_samples\model_348_samples.pkl - Training time: 10.53 ms
# Trained model for n=349 saved to models_all_samples\model_349_samples.pkl - Training time: 5.62 ms
# Trained model for n=350 saved to models_all_samples\model_350_samples.pkl - Training time: 6.69 ms
# Trained model for n=351 saved to models_all_samples\model_351_samples.pkl - Training time: 4.07 ms
# Trained model for n=352 saved to models_all_samples\model_352_samples.pkl - Training time: 5.57 ms
# Trained model for n=353 saved to models_all_samples\model_353_samples.pkl - Training time: 6.70 ms
# Trained model for n=354 saved to models_all_samples\model_354_samples.pkl - Training time: 7.45 ms
# Trained model for n=355 saved to models_all_samples\model_355_samples.pkl - Training time: 3.95 ms
# Trained model for n=356 saved to models_all_samples\model_356_samples.pkl - Training time: 4.59 ms
# Trained model for n=357 saved to models_all_samples\model_357_samples.pkl - Training time: 5.88 ms
# Trained model for n=358 saved to models_all_samples\model_358_samples.pkl - Training time: 6.67 ms
# Trained model for n=359 saved to models_all_samples\model_359_samples.pkl - Training time: 6.60 ms
# Trained model for n=360 saved to models_all_samples\model_360_samples.pkl - Training time: 4.91 ms
# Trained model for n=361 saved to models_all_samples\model_361_samples.pkl - Training time: 6.00 ms
# Trained model for n=362 saved to models_all_samples\model_362_samples.pkl - Training time: 5.00 ms
# Trained model for n=363 saved to models_all_samples\model_363_samples.pkl - Training time: 4.00 ms
# Trained model for n=364 saved to models_all_samples\model_364_samples.pkl - Training time: 5.53 ms
# Trained model for n=365 saved to models_all_samples\model_365_samples.pkl - Training time: 3.64 ms
# Trained model for n=366 saved to models_all_samples\model_366_samples.pkl - Training time: 4.00 ms
# Trained model for n=367 saved to models_all_samples\model_367_samples.pkl - Training time: 4.00 ms
# Trained model for n=368 saved to models_all_samples\model_368_samples.pkl - Training time: 9.24 ms
# Trained model for n=369 saved to models_all_samples\model_369_samples.pkl - Training time: 5.00 ms
# Trained model for n=370 saved to models_all_samples\model_370_samples.pkl - Training time: 5.51 ms
# Trained model for n=371 saved to models_all_samples\model_371_samples.pkl - Training time: 5.00 ms
# Trained model for n=372 saved to models_all_samples\model_372_samples.pkl - Training time: 3.50 ms
# Trained model for n=373 saved to models_all_samples\model_373_samples.pkl - Training time: 6.31 ms
# Trained model for n=374 saved to models_all_samples\model_374_samples.pkl - Training time: 4.70 ms
# Trained model for n=375 saved to models_all_samples\model_375_samples.pkl - Training time: 5.58 ms
# Trained model for n=376 saved to models_all_samples\model_376_samples.pkl - Training time: 6.00 ms
# Trained model for n=377 saved to models_all_samples\model_377_samples.pkl - Training time: 5.01 ms
# Trained model for n=378 saved to models_all_samples\model_378_samples.pkl - Training time: 7.54 ms
# Trained model for n=379 saved to models_all_samples\model_379_samples.pkl - Training time: 7.51 ms
# Trained model for n=380 saved to models_all_samples\model_380_samples.pkl - Training time: 5.00 ms
# Trained model for n=381 saved to models_all_samples\model_381_samples.pkl - Training time: 4.51 ms
# Trained model for n=382 saved to models_all_samples\model_382_samples.pkl - Training time: 4.00 ms
# Trained model for n=383 saved to models_all_samples\model_383_samples.pkl - Training time: 7.53 ms
# Trained model for n=384 saved to models_all_samples\model_384_samples.pkl - Training time: 5.52 ms
# Trained model for n=385 saved to models_all_samples\model_385_samples.pkl - Training time: 6.46 ms
# Trained model for n=386 saved to models_all_samples\model_386_samples.pkl - Training time: 5.57 ms
# Trained model for n=387 saved to models_all_samples\model_387_samples.pkl - Training time: 4.07 ms
# Trained model for n=388 saved to models_all_samples\model_388_samples.pkl - Training time: 6.02 ms
# Trained model for n=389 saved to models_all_samples\model_389_samples.pkl - Training time: 4.51 ms
# Trained model for n=390 saved to models_all_samples\model_390_samples.pkl - Training time: 4.94 ms
# Trained model for n=391 saved to models_all_samples\model_391_samples.pkl - Training time: 5.03 ms
# Trained model for n=392 saved to models_all_samples\model_392_samples.pkl - Training time: 5.54 ms
# Trained model for n=393 saved to models_all_samples\model_393_samples.pkl - Training time: 6.60 ms
# Trained model for n=394 saved to models_all_samples\model_394_samples.pkl - Training time: 6.56 ms
# Trained model for n=395 saved to models_all_samples\model_395_samples.pkl - Training time: 5.50 ms
# Trained model for n=396 saved to models_all_samples\model_396_samples.pkl - Training time: 6.54 ms
# Trained model for n=397 saved to models_all_samples\model_397_samples.pkl - Training time: 6.62 ms
# Trained model for n=398 saved to models_all_samples\model_398_samples.pkl - Training time: 5.60 ms
# Trained model for n=399 saved to models_all_samples\model_399_samples.pkl - Training time: 5.62 ms
# Trained model for n=400 saved to models_all_samples\model_400_samples.pkl - Training time: 4.68 ms
# Trained model for n=401 saved to models_all_samples\model_401_samples.pkl - Training time: 4.52 ms
# Trained model for n=402 saved to models_all_samples\model_402_samples.pkl - Training time: 6.50 ms
# Trained model for n=403 saved to models_all_samples\model_403_samples.pkl - Training time: 5.00 ms
# Trained model for n=404 saved to models_all_samples\model_404_samples.pkl - Training time: 7.54 ms
# Trained model for n=405 saved to models_all_samples\model_405_samples.pkl - Training time: 4.00 ms
# Trained model for n=406 saved to models_all_samples\model_406_samples.pkl - Training time: 5.62 ms
# Trained model for n=407 saved to models_all_samples\model_407_samples.pkl - Training time: 10.54 ms
# Trained model for n=408 saved to models_all_samples\model_408_samples.pkl - Training time: 5.00 ms
# Trained model for n=409 saved to models_all_samples\model_409_samples.pkl - Training time: 7.51 ms
# Trained model for n=410 saved to models_all_samples\model_410_samples.pkl - Training time: 5.98 ms
# Trained model for n=411 saved to models_all_samples\model_411_samples.pkl - Training time: 4.00 ms
# Trained model for n=412 saved to models_all_samples\model_412_samples.pkl - Training time: 6.55 ms
# Trained model for n=413 saved to models_all_samples\model_413_samples.pkl - Training time: 6.56 ms
# Trained model for n=414 saved to models_all_samples\model_414_samples.pkl - Training time: 6.02 ms
# Trained model for n=415 saved to models_all_samples\model_415_samples.pkl - Training time: 5.99 ms
# Trained model for n=416 saved to models_all_samples\model_416_samples.pkl - Training time: 6.01 ms
# Trained model for n=417 saved to models_all_samples\model_417_samples.pkl - Training time: 5.51 ms
# Trained model for n=418 saved to models_all_samples\model_418_samples.pkl - Training time: 8.71 ms
# Trained model for n=419 saved to models_all_samples\model_419_samples.pkl - Training time: 6.53 ms
# Trained model for n=420 saved to models_all_samples\model_420_samples.pkl - Training time: 10.56 ms
# Trained model for n=421 saved to models_all_samples\model_421_samples.pkl - Training time: 8.52 ms
# Trained model for n=422 saved to models_all_samples\model_422_samples.pkl - Training time: 6.52 ms
# Trained model for n=423 saved to models_all_samples\model_423_samples.pkl - Training time: 6.00 ms
# Trained model for n=424 saved to models_all_samples\model_424_samples.pkl - Training time: 6.52 ms
# Trained model for n=425 saved to models_all_samples\model_425_samples.pkl - Training time: 5.52 ms
# Trained model for n=426 saved to models_all_samples\model_426_samples.pkl - Training time: 6.62 ms
# Trained model for n=427 saved to models_all_samples\model_427_samples.pkl - Training time: 9.54 ms
# Trained model for n=428 saved to models_all_samples\model_428_samples.pkl - Training time: 14.05 ms
# Trained model for n=429 saved to models_all_samples\model_429_samples.pkl - Training time: 7.51 ms
# Trained model for n=430 saved to models_all_samples\model_430_samples.pkl - Training time: 5.00 ms
# Trained model for n=431 saved to models_all_samples\model_431_samples.pkl - Training time: 10.53 ms
# Trained model for n=432 saved to models_all_samples\model_432_samples.pkl - Training time: 5.93 ms
# Trained model for n=433 saved to models_all_samples\model_433_samples.pkl - Training time: 5.01 ms
# Trained model for n=434 saved to models_all_samples\model_434_samples.pkl - Training time: 6.08 ms
# Trained model for n=435 saved to models_all_samples\model_435_samples.pkl - Training time: 6.76 ms
# Trained model for n=436 saved to models_all_samples\model_436_samples.pkl - Training time: 6.01 ms
# Trained model for n=437 saved to models_all_samples\model_437_samples.pkl - Training time: 6.64 ms
# Trained model for n=438 saved to models_all_samples\model_438_samples.pkl - Training time: 5.74 ms
# Trained model for n=439 saved to models_all_samples\model_439_samples.pkl - Training time: 4.64 ms
# Trained model for n=440 saved to models_all_samples\model_440_samples.pkl - Training time: 5.49 ms
# Trained model for n=441 saved to models_all_samples\model_441_samples.pkl - Training time: 6.08 ms
# Trained model for n=442 saved to models_all_samples\model_442_samples.pkl - Training time: 6.07 ms
# Trained model for n=443 saved to models_all_samples\model_443_samples.pkl - Training time: 4.62 ms
# Trained model for n=444 saved to models_all_samples\model_444_samples.pkl - Training time: 5.52 ms
# Trained model for n=445 saved to models_all_samples\model_445_samples.pkl - Training time: 6.54 ms
# Trained model for n=446 saved to models_all_samples\model_446_samples.pkl - Training time: 6.51 ms
# Trained model for n=447 saved to models_all_samples\model_447_samples.pkl - Training time: 6.00 ms
# Trained model for n=448 saved to models_all_samples\model_448_samples.pkl - Training time: 10.59 ms
# Trained model for n=449 saved to models_all_samples\model_449_samples.pkl - Training time: 9.54 ms
# Trained model for n=450 saved to models_all_samples\model_450_samples.pkl - Training time: 6.57 ms
# Trained model for n=451 saved to models_all_samples\model_451_samples.pkl - Training time: 7.02 ms
# Trained model for n=452 saved to models_all_samples\model_452_samples.pkl - Training time: 6.50 ms
# Trained model for n=453 saved to models_all_samples\model_453_samples.pkl - Training time: 6.58 ms
# Trained model for n=454 saved to models_all_samples\model_454_samples.pkl - Training time: 8.53 ms
# Trained model for n=455 saved to models_all_samples\model_455_samples.pkl - Training time: 6.67 ms
# Trained model for n=456 saved to models_all_samples\model_456_samples.pkl - Training time: 9.62 ms
# Trained model for n=457 saved to models_all_samples\model_457_samples.pkl - Training time: 6.04 ms
# Trained model for n=458 saved to models_all_samples\model_458_samples.pkl - Training time: 7.07 ms
# Trained model for n=459 saved to models_all_samples\model_459_samples.pkl - Training time: 7.63 ms
# Trained model for n=460 saved to models_all_samples\model_460_samples.pkl - Training time: 8.68 ms
# Trained model for n=461 saved to models_all_samples\model_461_samples.pkl - Training time: 12.25 ms
# Trained model for n=462 saved to models_all_samples\model_462_samples.pkl - Training time: 7.39 ms
# Trained model for n=463 saved to models_all_samples\model_463_samples.pkl - Training time: 9.50 ms
# Trained model for n=464 saved to models_all_samples\model_464_samples.pkl - Training time: 6.04 ms
# Trained model for n=465 saved to models_all_samples\model_465_samples.pkl - Training time: 7.01 ms
# Trained model for n=466 saved to models_all_samples\model_466_samples.pkl - Training time: 7.51 ms
# Trained model for n=467 saved to models_all_samples\model_467_samples.pkl - Training time: 7.52 ms
# Trained model for n=468 saved to models_all_samples\model_468_samples.pkl - Training time: 5.00 ms
# Trained model for n=469 saved to models_all_samples\model_469_samples.pkl - Training time: 11.60 ms
# Trained model for n=470 saved to models_all_samples\model_470_samples.pkl - Training time: 7.08 ms
# Trained model for n=471 saved to models_all_samples\model_471_samples.pkl - Training time: 4.02 ms
# Trained model for n=472 saved to models_all_samples\model_472_samples.pkl - Training time: 5.02 ms
# Trained model for n=473 saved to models_all_samples\model_473_samples.pkl - Training time: 9.89 ms
# Trained model for n=474 saved to models_all_samples\model_474_samples.pkl - Training time: 6.08 ms
# Trained model for n=475 saved to models_all_samples\model_475_samples.pkl - Training time: 6.01 ms
# Trained model for n=476 saved to models_all_samples\model_476_samples.pkl - Training time: 7.87 ms
# Trained model for n=477 saved to models_all_samples\model_477_samples.pkl - Training time: 6.05 ms
# Trained model for n=478 saved to models_all_samples\model_478_samples.pkl - Training time: 5.57 ms
# Trained model for n=479 saved to models_all_samples\model_479_samples.pkl - Training time: 7.57 ms
# Trained model for n=480 saved to models_all_samples\model_480_samples.pkl - Training time: 8.01 ms
# Trained model for n=481 saved to models_all_samples\model_481_samples.pkl - Training time: 7.29 ms
# Trained model for n=482 saved to models_all_samples\model_482_samples.pkl - Training time: 4.09 ms
# Trained model for n=483 saved to models_all_samples\model_483_samples.pkl - Training time: 6.56 ms
# Trained model for n=484 saved to models_all_samples\model_484_samples.pkl - Training time: 7.51 ms
# Trained model for n=485 saved to models_all_samples\model_485_samples.pkl - Training time: 4.01 ms
# Trained model for n=486 saved to models_all_samples\model_486_samples.pkl - Training time: 7.54 ms
# ...
# Trained model for n=2349 saved to models_all_samples\model_2349_samples.pkl - Training time: 22.22 ms
# Trained model for n=2350 saved to models_all_samples\model_2350_samples.pkl - Training time: 22.76 ms
# Trained model for n=2351 saved to models_all_samples\model_2351_samples.pkl - Training time: 25.17 ms
# Trained model for n=2352 saved to models_all_samples\model_2352_samples.pkl - Training time: 22.74 ms
# Trained model for n=2353 saved to models_all_samples\model_2353_samples.pkl - Training time: 25.95 ms
# Trained model for n=2354 saved to models_all_samples\model_2354_samples.pkl - Training time: 22.27 ms
# Trained model for n=2355 saved to models_all_samples\model_2355_samples.pkl - Training time: 25.20 ms
# Trained model for n=2356 saved to models_all_samples\model_2356_samples.pkl - Training time: 22.87 ms
# Trained model for n=2357 saved to models_all_samples\model_2357_samples.pkl - Training time: 25.71 ms
# Trained model for n=2358 saved to models_all_samples\model_2358_samples.pkl - Training time: 21.76 ms
# Trained model for n=2359 saved to models_all_samples\model_2359_samples.pkl - Training time: 22.73 ms
# Trained model for n=2360 saved to models_all_samples\model_2360_samples.pkl - Training time: 33.11 ms
# Trained model for n=2361 saved to models_all_samples\model_2361_samples.pkl - Training time: 28.65 ms
# Trained model for n=2362 saved to models_all_samples\model_2362_samples.pkl - Training time: 20.29 ms
# Trained model for n=2363 saved to models_all_samples\model_2363_samples.pkl - Training time: 24.12 ms
# Trained model for n=2364 saved to models_all_samples\model_2364_samples.pkl - Training time: 25.67 ms
# Trained model for n=2365 saved to models_all_samples\model_2365_samples.pkl - Training time: 23.65 ms
# Trained model for n=2366 saved to models_all_samples\model_2366_samples.pkl - Training time: 36.41 ms
# Trained model for n=2367 saved to models_all_samples\model_2367_samples.pkl - Training time: 24.56 ms
# Trained model for n=2368 saved to models_all_samples\model_2368_samples.pkl - Training time: 29.76 ms
# Trained model for n=2369 saved to models_all_samples\model_2369_samples.pkl - Training time: 21.06 ms
# Trained model for n=2370 saved to models_all_samples\model_2370_samples.pkl - Training time: 25.76 ms
# Trained model for n=2371 saved to models_all_samples\model_2371_samples.pkl - Training time: 26.06 ms
# Trained model for n=2372 saved to models_all_samples\model_2372_samples.pkl - Training time: 23.70 ms
# Trained model for n=2373 saved to models_all_samples\model_2373_samples.pkl - Training time: 24.88 ms
# Trained model for n=2374 saved to models_all_samples\model_2374_samples.pkl - Training time: 34.45 ms
# Trained model for n=2375 saved to models_all_samples\model_2375_samples.pkl - Training time: 29.35 ms
# Trained model for n=2376 saved to models_all_samples\model_2376_samples.pkl - Training time: 19.97 ms
# Trained model for n=2377 saved to models_all_samples\model_2377_samples.pkl - Training time: 33.83 ms
# Trained model for n=2378 saved to models_all_samples\model_2378_samples.pkl - Training time: 28.96 ms
# Trained model for n=2379 saved to models_all_samples\model_2379_samples.pkl - Training time: 24.57 ms
# Trained model for n=2380 saved to models_all_samples\model_2380_samples.pkl - Training time: 24.70 ms
# Trained model for n=2381 saved to models_all_samples\model_2381_samples.pkl - Training time: 26.34 ms
# Trained model for n=2382 saved to models_all_samples\model_2382_samples.pkl - Training time: 28.65 ms
# Trained model for n=2383 saved to models_all_samples\model_2383_samples.pkl - Training time: 26.00 ms
# Trained model for n=2384 saved to models_all_samples\model_2384_samples.pkl - Training time: 33.11 ms
# Trained model for n=2385 saved to models_all_samples\model_2385_samples.pkl - Training time: 22.21 ms
# Trained model for n=2386 saved to models_all_samples\model_2386_samples.pkl - Training time: 25.60 ms
# Trained model for n=2387 saved to models_all_samples\model_2387_samples.pkl - Training time: 24.03 ms
# Trained model for n=2388 saved to models_all_samples\model_2388_samples.pkl - Training time: 25.28 ms
# Trained model for n=2389 saved to models_all_samples\model_2389_samples.pkl - Training time: 23.86 ms
# Trained model for n=2390 saved to models_all_samples\model_2390_samples.pkl - Training time: 28.71 ms
# Trained model for n=2391 saved to models_all_samples\model_2391_samples.pkl - Training time: 28.97 ms
# Trained model for n=2392 saved to models_all_samples\model_2392_samples.pkl - Training time: 32.10 ms
# Trained model for n=2393 saved to models_all_samples\model_2393_samples.pkl - Training time: 30.54 ms
# Trained model for n=2394 saved to models_all_samples\model_2394_samples.pkl - Training time: 24.03 ms
# Trained model for n=2395 saved to models_all_samples\model_2395_samples.pkl - Training time: 26.54 ms
# Trained model for n=2396 saved to models_all_samples\model_2396_samples.pkl - Training time: 25.83 ms
# Trained model for n=2397 saved to models_all_samples\model_2397_samples.pkl - Training time: 26.20 ms
# Trained model for n=2398 saved to models_all_samples\model_2398_samples.pkl - Training time: 23.06 ms
# Trained model for n=2399 saved to models_all_samples\model_2399_samples.pkl - Training time: 21.55 ms
# Trained model for n=2400 saved to models_all_samples\model_2400_samples.pkl - Training time: 26.54 ms
# Trained model for n=2401 saved to models_all_samples\model_2401_samples.pkl - Training time: 23.28 ms
# Trained model for n=2402 saved to models_all_samples\model_2402_samples.pkl - Training time: 25.82 ms
# Trained model for n=2403 saved to models_all_samples\model_2403_samples.pkl - Training time: 22.06 ms
# Trained model for n=2404 saved to models_all_samples\model_2404_samples.pkl - Training time: 33.26 ms
# Trained model for n=2405 saved to models_all_samples\model_2405_samples.pkl - Training time: 42.80 ms
# Trained model for n=2406 saved to models_all_samples\model_2406_samples.pkl - Training time: 26.09 ms
# Trained model for n=2407 saved to models_all_samples\model_2407_samples.pkl - Training time: 23.27 ms
# Trained model for n=2408 saved to models_all_samples\model_2408_samples.pkl - Training time: 27.68 ms
# Trained model for n=2409 saved to models_all_samples\model_2409_samples.pkl - Training time: 25.50 ms
# Trained model for n=2410 saved to models_all_samples\model_2410_samples.pkl - Training time: 63.17 ms
# Trained model for n=2411 saved to models_all_samples\model_2411_samples.pkl - Training time: 29.55 ms
# Trained model for n=2412 saved to models_all_samples\model_2412_samples.pkl - Training time: 25.56 ms
# Trained model for n=2413 saved to models_all_samples\model_2413_samples.pkl - Training time: 26.05 ms
# Trained model for n=2414 saved to models_all_samples\model_2414_samples.pkl - Training time: 57.53 ms
# Trained model for n=2415 saved to models_all_samples\model_2415_samples.pkl - Training time: 54.81 ms
# Trained model for n=2416 saved to models_all_samples\model_2416_samples.pkl - Training time: 27.22 ms
# Trained model for n=2417 saved to models_all_samples\model_2417_samples.pkl - Training time: 35.56 ms
# Trained model for n=2418 saved to models_all_samples\model_2418_samples.pkl - Training time: 74.59 ms
# Trained model for n=2419 saved to models_all_samples\model_2419_samples.pkl - Training time: 28.12 ms
# Trained model for n=2420 saved to models_all_samples\model_2420_samples.pkl - Training time: 28.67 ms
# Trained model for n=2421 saved to models_all_samples\model_2421_samples.pkl - Training time: 28.80 ms
# Trained model for n=2422 saved to models_all_samples\model_2422_samples.pkl - Training time: 34.03 ms
# Trained model for n=2423 saved to models_all_samples\model_2423_samples.pkl - Training time: 31.51 ms
# Trained model for n=2424 saved to models_all_samples\model_2424_samples.pkl - Training time: 29.77 ms
# Trained model for n=2425 saved to models_all_samples\model_2425_samples.pkl - Training time: 27.48 ms
# Trained model for n=2426 saved to models_all_samples\model_2426_samples.pkl - Training time: 43.30 ms
# Trained model for n=2427 saved to models_all_samples\model_2427_samples.pkl - Training time: 33.43 ms
# Trained model for n=2428 saved to models_all_samples\model_2428_samples.pkl - Training time: 27.04 ms
# Trained model for n=2429 saved to models_all_samples\model_2429_samples.pkl - Training time: 28.61 ms
# Trained model for n=2430 saved to models_all_samples\model_2430_samples.pkl - Training time: 28.18 ms
# Trained model for n=2431 saved to models_all_samples\model_2431_samples.pkl - Training time: 25.48 ms
# Trained model for n=2432 saved to models_all_samples\model_2432_samples.pkl - Training time: 54.63 ms
# Trained model for n=2433 saved to models_all_samples\model_2433_samples.pkl - Training time: 31.58 ms
# Trained model for n=2434 saved to models_all_samples\model_2434_samples.pkl - Training time: 24.97 ms
# Trained model for n=2435 saved to models_all_samples\model_2435_samples.pkl - Training time: 24.67 ms
# Trained model for n=2436 saved to models_all_samples\model_2436_samples.pkl - Training time: 34.05 ms
# Trained model for n=2437 saved to models_all_samples\model_2437_samples.pkl - Training time: 24.86 ms
# Trained model for n=2438 saved to models_all_samples\model_2438_samples.pkl - Training time: 30.05 ms
# Trained model for n=2439 saved to models_all_samples\model_2439_samples.pkl - Training time: 31.44 ms
# Trained model for n=2440 saved to models_all_samples\model_2440_samples.pkl - Training time: 22.69 ms
# Trained model for n=2441 saved to models_all_samples\model_2441_samples.pkl - Training time: 26.66 ms
# Trained model for n=2442 saved to models_all_samples\model_2442_samples.pkl - Training time: 25.77 ms
# Trained model for n=2443 saved to models_all_samples\model_2443_samples.pkl - Training time: 25.89 ms
# Trained model for n=2444 saved to models_all_samples\model_2444_samples.pkl - Training time: 31.94 ms
# Trained model for n=2445 saved to models_all_samples\model_2445_samples.pkl - Training time: 24.56 ms
# Trained model for n=2446 saved to models_all_samples\model_2446_samples.pkl - Training time: 33.50 ms
# Trained model for n=2447 saved to models_all_samples\model_2447_samples.pkl - Training time: 26.74 ms
# Trained model for n=2448 saved to models_all_samples\model_2448_samples.pkl - Training time: 25.56 ms
# Trained model for n=2449 saved to models_all_samples\model_2449_samples.pkl - Training time: 33.32 ms
# Trained model for n=2450 saved to models_all_samples\model_2450_samples.pkl - Training time: 47.08 ms
# Trained model for n=2451 saved to models_all_samples\model_2451_samples.pkl - Training time: 28.28 ms
# Trained model for n=2452 saved to models_all_samples\model_2452_samples.pkl - Training time: 23.83 ms
# Trained model for n=2453 saved to models_all_samples\model_2453_samples.pkl - Training time: 24.96 ms
# Trained model for n=2454 saved to models_all_samples\model_2454_samples.pkl - Training time: 23.24 ms
# Trained model for n=2455 saved to models_all_samples\model_2455_samples.pkl - Training time: 25.41 ms
# Trained model for n=2456 saved to models_all_samples\model_2456_samples.pkl - Training time: 25.62 ms
# Trained model for n=2457 saved to models_all_samples\model_2457_samples.pkl - Training time: 25.20 ms
# Trained model for n=2458 saved to models_all_samples\model_2458_samples.pkl - Training time: 25.61 ms
# Trained model for n=2459 saved to models_all_samples\model_2459_samples.pkl - Training time: 24.62 ms
# Trained model for n=2460 saved to models_all_samples\model_2460_samples.pkl - Training time: 29.56 ms
# Trained model for n=2461 saved to models_all_samples\model_2461_samples.pkl - Training time: 23.96 ms
# Trained model for n=2462 saved to models_all_samples\model_2462_samples.pkl - Training time: 23.99 ms
# Trained model for n=2463 saved to models_all_samples\model_2463_samples.pkl - Training time: 23.37 ms
# Trained model for n=2464 saved to models_all_samples\model_2464_samples.pkl - Training time: 25.73 ms
# Trained model for n=2465 saved to models_all_samples\model_2465_samples.pkl - Training time: 28.43 ms
# Trained model for n=2466 saved to models_all_samples\model_2466_samples.pkl - Training time: 22.68 ms
# Trained model for n=2467 saved to models_all_samples\model_2467_samples.pkl - Training time: 27.45 ms
# Trained model for n=2468 saved to models_all_samples\model_2468_samples.pkl - Training time: 37.04 ms
# Trained model for n=2469 saved to models_all_samples\model_2469_samples.pkl - Training time: 26.86 ms
# Trained model for n=2470 saved to models_all_samples\model_2470_samples.pkl - Training time: 26.04 ms
# Trained model for n=2471 saved to models_all_samples\model_2471_samples.pkl - Training time: 74.70 ms
# Trained model for n=2472 saved to models_all_samples\model_2472_samples.pkl - Training time: 26.59 ms
# Trained model for n=2473 saved to models_all_samples\model_2473_samples.pkl - Training time: 29.13 ms
# Trained model for n=2474 saved to models_all_samples\model_2474_samples.pkl - Training time: 29.40 ms
# Trained model for n=2475 saved to models_all_samples\model_2475_samples.pkl - Training time: 30.77 ms
# Trained model for n=2476 saved to models_all_samples\model_2476_samples.pkl - Training time: 26.35 ms
# Trained model for n=2477 saved to models_all_samples\model_2477_samples.pkl - Training time: 24.06 ms
# Trained model for n=2478 saved to models_all_samples\model_2478_samples.pkl - Training time: 25.43 ms
# Trained model for n=2479 saved to models_all_samples\model_2479_samples.pkl - Training time: 24.08 ms
# Trained model for n=2480 saved to models_all_samples\model_2480_samples.pkl - Training time: 26.05 ms
# Trained model for n=2481 saved to models_all_samples\model_2481_samples.pkl - Training time: 27.16 ms
# Trained model for n=2482 saved to models_all_samples\model_2482_samples.pkl - Training time: 24.72 ms
# Trained model for n=2483 saved to models_all_samples\model_2483_samples.pkl - Training time: 26.02 ms
# Trained model for n=2484 saved to models_all_samples\model_2484_samples.pkl - Training time: 26.03 ms
# Trained model for n=2485 saved to models_all_samples\model_2485_samples.pkl - Training time: 26.32 ms
# Trained model for n=2486 saved to models_all_samples\model_2486_samples.pkl - Training time: 26.54 ms
# Trained model for n=2487 saved to models_all_samples\model_2487_samples.pkl - Training time: 24.41 ms
# Trained model for n=2488 saved to models_all_samples\model_2488_samples.pkl - Training time: 24.93 ms
# Trained model for n=2489 saved to models_all_samples\model_2489_samples.pkl - Training time: 24.01 ms
# Trained model for n=2490 saved to models_all_samples\model_2490_samples.pkl - Training time: 25.09 ms
# Trained model for n=2491 saved to models_all_samples\model_2491_samples.pkl - Training time: 24.95 ms
# Trained model for n=2492 saved to models_all_samples\model_2492_samples.pkl - Training time: 26.21 ms
# Trained model for n=2493 saved to models_all_samples\model_2493_samples.pkl - Training time: 26.74 ms
# Trained model for n=2494 saved to models_all_samples\model_2494_samples.pkl - Training time: 29.17 ms
# Trained model for n=2495 saved to models_all_samples\model_2495_samples.pkl - Training time: 38.20 ms
# Trained model for n=2496 saved to models_all_samples\model_2496_samples.pkl - Training time: 28.12 ms
# Trained model for n=2497 saved to models_all_samples\model_2497_samples.pkl - Training time: 40.68 ms
# Trained model for n=2498 saved to models_all_samples\model_2498_samples.pkl - Training time: 24.29 ms
# Trained model for n=2499 saved to models_all_samples\model_2499_samples.pkl - Training time: 27.07 ms
# Trained model for n=2500 saved to models_all_samples\model_2500_samples.pkl - Training time: 35.90 ms
# Trained model for n=2501 saved to models_all_samples\model_2501_samples.pkl - Training time: 23.09 ms
# Trained model for n=2502 saved to models_all_samples\model_2502_samples.pkl - Training time: 24.09 ms
# Trained model for n=2503 saved to models_all_samples\model_2503_samples.pkl - Training time: 27.88 ms
# Trained model for n=2504 saved to models_all_samples\model_2504_samples.pkl - Training time: 29.37 ms
# Training times saved to training_times.csv

# %% [markdown]
# ## 5. Analyzing Model Performance with Fixed Test Data
#
# The script assesses the impact of different sample sizes on model training and evaluates how well the trained models generalize to the fixed test data.
#
# ### Purpose
#
# The primary purpose of this script is to analyze the relationship between sample size and model performance using a consistent test dataset. The script calculates the Root Mean Squared Error (RMSE) for each trained model and plots the RMSE values against different sample sizes. This analysis aids in understanding how the choice of sample size influences model accuracy.
#
# ### Workflow
#
# 1. **Test Data Loading**:
#    The script loads the fixed test data from log files in the "data_filtered" folder, extracting necessary information for evaluation.
#
# 2. **Trained Model Iteration**:
#    For each sample size in the range from 1 to 677, the script loads the corresponding trained model from the "models_all_samples" folder.
#
# 3. **Prediction and RMSE Calculation**:
#    Predictions are made on the fixed test dataset using the loaded model. The Root Mean Squared Error (RMSE) is then calculated to assess prediction accuracy.
#
# 4. **Optimal Sample Size Identification**:
#    The script tracks the sample size that results in the lowest RMSE value, enabling the identification of an optimal training sample size for the model.
#
# 5. **RMSE vs. Sample Size Plotting**:
#    A plot is generated to visualize the relationship between sample size and RMSE values. This graph helps to understand how different sample sizes affect model performance.
#
# ### Insights and Decision Making
#
# By executing this script, practitioners gain valuable insights:
#
# - The sample size leading to the lowest RMSE value provides guidance on selecting an effective training data volume that balances model accuracy and resource efficiency.
#
# - The RMSE vs. Sample Size plot visually illustrates the correlation between training data size and model performance, aiding in informed decision-making.
#
# ### Practical Usage
#
# 1. **Test Data and Trained Models**: Ensure the "data_filtered" folder contains the fixed test log files, and the "models_all_samples" folder stores trained models.
#
# 2. **Executing the Script**: Run the script to calculate RMSE values for each sample size and identify the optimal sample size based on the lowest RMSE.
#
# 3. **Interpreting Output**: Examine the script's output to determine the sample size that results in the best compromise between model accuracy and computational efficiency.
#
# 4. **Graph Visualization**: Analyze the generated RMSE vs. Sample Size graph to comprehend the trend in model performance as training data size varies.
#
# Through this script's analysis and visualization, data scientists can make informed choices about the ideal sample size for their specific model training needs.

# %%
import os
import joblib
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

data_test_folder = "data_test"
models_folder = "models_all_samples"  # Folder where trained models are saved

# Load all test data into memory
X_test = []
y_test = []

for log_file in os.listdir(data_test_folder):
    if log_file.endswith(".log"):
        input_file_path = os.path.join(data_test_folder, log_file)
        with open(input_file_path, "r") as file:
            lines = file.readlines()
            for line in lines:
                if line.startswith("POS"):
                    try:
                        data = line.strip().split(",")
                        x = [float(data[1]), float(data[2]), float(data[3])]  # Measured position in meters
                        real_point = [float(val)/100 for val in os.path.splitext(os.path.basename(log_file))[0].split('_')]  # Real point in centimeters
                        X_test.append(x)
                        y_test.append(real_point)
                    except:
                        print(line)

# Convert lists to arrays
X_test = np.array(X_test)
y_test = np.array(y_test)

# Initialize variables to store data
n_values = []
rmse_values = []

min_error = float("inf")  # Initialize with a large value
min_error_n = None

# Iterate over the range of n values
for n in range(1, nb_samples):
    model_filename = os.path.join(models_folder, f"model_{n}_samples.pkl")

    # Load the trained model
    model = joblib.load(model_filename)

    # Initialize variables to calculate RMSE
    squared_errors = []

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Evaluate the model
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    if rmse < min_error:
        min_error = rmse
        min_error_n = n

    # Append data to lists
    n_values.append(n)
    rmse_values.append(rmse)

print(f"Minimum RMSE: {min_error} at n = {min_error_n}")

# Plotting the graph
plt.figure()
plt.plot(n_values, rmse_values, marker='o', linestyle='-', color='b')
plt.xlabel("Number of Samples (n)")
plt.ylabel("Root Mean Squared Error (RMSE)")
plt.title("RMSE vs Number of Samples")
plt.grid(True)
plt.show()
# Out:
# POS,-0.11,-0.48,-0.1POS,-0.06,-0.60,0.02,90
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 42
#      39 min_error_n = None
#      41 # Iterate over the range of n values
# ---> 42 for n in range(1, nb_samples):
#      43     model_filename = os.path.join(models_folder, f"model_{n}_samples.pkl")
#      45     # Load the trained model
#
# NameError: name 'nb_samples' is not defined

# %% [markdown]
# According to the graph n = 733 (chat GPT)

# %%
import joblib
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

model_path = "models_all_samples/model_733_samples.pkl"
log_folder = "data_filtered"

# Assuming you have already trained and saved the model
# Load the model from the saved file
loaded_model = joblib.load(model_path)

def read_log_file(file_path):
    # Read the data from the log file and return a numpy array of positions in meters
    # (assuming the data is a single-column containing the measured positions)
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            if line.startswith("POS"):
                try:
                    d = line.strip().split(",")
                    x = [float(d[1]), float(d[2]), float(d[3])]
                    data.append(x)
                except:
                    print(line)
    return np.array(data)

def calculate_error(real_position, measured_positions):
    # Calculate the error in distance from the real position
    error_data = []
    for measured_position in measured_positions:
        error = np.linalg.norm(measured_position - real_position)
        error_data.append(error)
    return np.array(error_data)

def plot_combined_gaussian_graph(errors_before_model, errors_after_model):
    # Create a new figure
    fig, ax = plt.subplots(figsize=(13, 7))

    # Fit Gaussian distributions to the error data
    mu_before, std_before = norm.fit(errors_before_model)
    mu_after, std_after = norm.fit(errors_after_model)

    x_range = np.linspace(min(errors_before_model + errors_after_model), max(errors_before_model + errors_after_model), 100)
    gaussian_curve_before = norm.pdf(x_range, mu_before, std_before)  # Gaussian curve for before model
    gaussian_curve_after = norm.pdf(x_range, mu_after, std_after)  # Gaussian curve for after model

    ax.plot(x_range, gaussian_curve_before, label="Before Model Gaussian Distribution")
    ax.plot(x_range, gaussian_curve_after, label="After Model Gaussian Distribution")
    ax.hist(errors_before_model, bins='auto', alpha=0.7, density=True, label="Before Model Error Histogram")
    ax.hist(errors_after_model, bins='auto', alpha=0.7, density=True, label="After Model Error Histogram")

    ax.set_xlim(0)  # Set x-axis limit to start from 0
    ax.set_ylim(0)  # Set y-axis limit to start from 0

    ax.set_xlabel("Error in Distance from Real Position (m)")
    ax.set_ylabel("Occurrences (Density)")
    ax.set_title("Combined Gaussian Graph for Error Distributions")
    ax.legend()
    ax.grid(True)

    # Set x-axis ticks with 0.1 interval
    x_ticks = np.arange(0, max(errors_before_model + errors_after_model) + 0.1, 0.1)
    ax.set_xticks(x_ticks)

    # Calculate and display average errors
    avg_error_before = np.mean(errors_before_model)
    avg_error_after = np.mean(errors_after_model)
      # Adjust the position of the average error text to upper right corner
    ax.text(0.95, 0.5, f'Avg Error Before Model: {avg_error_before:.3f}', transform=ax.transAxes, ha='right', va='top')
    ax.text(0.94, 0.4, f'Avg Error After Model: {avg_error_after:.3f}', transform=ax.transAxes, ha='right', va='top')

    plt.tight_layout()  # Apply tight layout to the graph
    plt.show()

def main():
    log_files = [f for f in os.listdir(log_folder) if f.endswith(".log")]

    all_errors_before_model = []  # Collect errors before using the model
    all_errors_after_model = []  # Collect errors after using the model

    for log_file in log_files:
        # Extract x, y, and z from the log file name
        real_position = [float(val)/100 for val in os.path.splitext(os.path.basename(log_file))[0].split('_')]

        # Read data from the log file
        file_path = os.path.join(log_folder, log_file)
        measured_positions = read_log_file(file_path)

        # Calculate errors before using the model
        pre_trained_errors = calculate_error(real_position, measured_positions)
        all_errors_before_model.extend(pre_trained_errors)  # Add errors to the list

        # Use the model to predict
        predictions = loaded_model.predict(measured_positions)

        # Calculate errors after using the model
        trained_errors = calculate_error(real_position, predictions)
        all_errors_after_model.extend(trained_errors)  # Add errors to the list

    # Plot combined Gaussian graph for errors before and after using the model
    plot_combined_gaussian_graph(all_errors_before_model, all_errors_after_model)

if __name__ == "__main__":
    main()

# %%
import joblib
import os
import re
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

model_path = "models_all_samples/model_733_samples.pkl"
log_folder = "data_ext/train"

# Assuming you have already trained and saved the model
# Load the model from the saved file
loaded_model = joblib.load(model_path)

def read_log_file(file_path):
    # Read the data from the log file and return a numpy array of positions in meters
    # (assuming the data is a single-column containing the measured positions)
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            if line.startswith("POS"):
                try:
                    d = line.strip().split(",")
                    x = [float(d[1]), float(d[2]), float(d[3])]
                    data.append(x)
                except:
                    print(line)
    return np.array(data)

def calculate_error(real_position, measured_positions):
    # Calculate the error in distance from the real position
    error_data = []
    for measured_position in measured_positions:
        error = np.linalg.norm(measured_position - real_position)
        error_data.append(error)
    return np.array(error_data)

def plot_combined_gaussian_graph(errors_before_model, errors_after_model):
    # Create a new figure
    fig, ax = plt.subplots(figsize=(13, 7))

    # Fit Gaussian distributions to the error data
    mu_before, std_before = norm.fit(errors_before_model)
    mu_after, std_after = norm.fit(errors_after_model)

    x_range = np.linspace(min(errors_before_model + errors_after_model), max(errors_before_model + errors_after_model), 100)
    gaussian_curve_before = norm.pdf(x_range, mu_before, std_before)  # Gaussian curve for before model
    gaussian_curve_after = norm.pdf(x_range, mu_after, std_after)  # Gaussian curve for after model

    ax.plot(x_range, gaussian_curve_before, label="Before Model Gaussian Distribution")
    ax.plot(x_range, gaussian_curve_after, label="After Model Gaussian Distribution")
    ax.hist(errors_before_model, bins='auto', alpha=0.7, density=True, label="Before Model Error Histogram")
    ax.hist(errors_after_model, bins='auto', alpha=0.7, density=True, label="After Model Error Histogram")

    ax.set_xlim(0)  # Set x-axis limit to start from 0
    ax.set_ylim(0)  # Set y-axis limit to start from 0

    ax.set_xlabel("Error in Distance from Real Position (m)")
    ax.set_ylabel("Occurrences (Density)")
    ax.set_title("Combined Gaussian Graph for Error Distributions")
    ax.legend()
    ax.grid(True)

    # Set x-axis ticks with 0.1 interval
    x_ticks = np.arange(0, max(errors_before_model + errors_after_model) + 0.1, 0.1)
    ax.set_xticks(x_ticks)

    # Calculate and display average errors
    avg_error_before = np.mean(errors_before_model)
    avg_error_after = np.mean(errors_after_model)
      # Adjust the position of the average error text to upper right corner
    ax.text(0.95, 0.5, f'Avg Error Before Model: {avg_error_before:.3f}', transform=ax.transAxes, ha='right', va='top')
    ax.text(0.94, 0.4, f'Avg Error After Model: {avg_error_after:.3f}', transform=ax.transAxes, ha='right', va='top')

    plt.tight_layout()  # Apply tight layout to the graph
    plt.show()

def main():
    log_files = [f for f in os.listdir(log_folder) if f.endswith(".log")]

    all_errors_before_model = []  # Collect errors before using the model
    all_errors_after_model = []  # Collect errors after using the model

    for log_file in log_files:
        # Extract x, y, and z from the log file name
        real_position = [float(val)/100 for val in os.path.splitext(os.path.basename(log_file))[0].split('_')]

        # Read data from the log file
        file_path = os.path.join(log_folder, log_file)
        measured_positions = read_log_file(file_path)

        # Calculate errors before using the model
        pre_trained_errors = calculate_error(real_position, measured_positions)
        all_errors_before_model.extend(pre_trained_errors)  # Add errors to the list

        # Use the model to predict
        predictions = loaded_model.predict(measured_positions)

        # Calculate errors after using the model
        trained_errors = calculate_error(real_position, predictions)
        all_errors_after_model.extend(trained_errors)  # Add errors to the list

    # Plot combined Gaussian graph for errors before and after using the model
    plot_combined_gaussian_graph(all_errors_before_model, all_errors_after_model)

if __name__ == "__main__":
    main()
# Out:
# POS,-POS,-0.07,-0.40,0.14,86

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

model_path = "models_all_samples/model_733_samples.pkl"
log_file = "data_ext/mobile/ziczac_2_1.log"

# Assuming you have already trained and saved the model
# Load the model from the saved file
loaded_model = joblib.load(model_path)

# Read data from the log file
data = []
with open(log_file, 'r') as file:
    for line in file:
        try:
            _, x, y, z, _ = line.strip().split(',')
            data.append([float(x), float(y), float(z)])
        except ValueError:
            pass  # Skip lines with errors

predictions = loaded_model.predict(data)
x_pred, y_pred, z_pred = zip(*predictions)
# Unpack data into separate lists for x, y, and z coordinates
x_data, y_data, z_data = zip(*data)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the data
ax.scatter(x_data, y_data, z_data, c='b', marker='o')
ax.scatter(x_pred, y_pred, z_pred, c='r', marker='o')

# Set labels for the axes
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Show the plot
plt.show()
